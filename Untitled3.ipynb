# %%
from pathlib import Path
import pickle
import numpy as np
import pandas as pd
from util import read_pickle

# %%
base_dir = Path('.')
data_dir = base_dir.joinpath('data')

# %%
genre = 'mandopop'
# Basic directories
base_dir = Path('.')
data_dir = base_dir.joinpath("data")
# read in song info
fid = data_dir.joinpath(f'songs_{genre}.pkl')
song_dat = read_pickle(fid)
# analysis features
audio_fts = ['danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms','year']

# %%
song_dat
# Out:
#                       song_id  \
# 0      1i31BYKv1La3wVC6VbgGui
# 1      77uwbOEaj6nMy6TlpEJg9Y
# 2      5OR1Fbd7RSI18OoBVhgTAf
# 3      7MmT3xzugKweEtethQiUeh
# 4      4vlzCpNsDFBaW99mrCGpmO
# ...                       ...
# 90207  19DMSeSsfWaaUPNli1ojLi
# 90208  4GFhd6PIhuvnXoJdwFl4Gz
# 90209  4ggMtQb4qP53E0uSpeBOAN
# 90210  0OVuhaotLVLmjuhoQYhRci
# 90211  62wkedajcnKd8Thn8yHQNJ
#
#                                              preview_url  popularity  \
# 0      https://p.scdn.co/mp3-preview/1a4604b2f86debd3...          30
# 1      https://p.scdn.co/mp3-preview/0eebe61274009d19...          29
# 2      https://p.scdn.co/mp3-preview/4fb6004d1b86271c...          31
# 3      https://p.scdn.co/mp3-preview/04b69da2b70636f7...          28
# 4      https://p.scdn.co/mp3-preview/c948a6357454ce02...          39
# ...                                                  ...         ...
# 90207  https://p.scdn.co/mp3-preview/0de61df8c6dd4388...           2
# 90208  https://p.scdn.co/mp3-preview/c5683c374cca6e8a...           2
# 90209  https://p.scdn.co/mp3-preview/d6ed0b113c89f52e...           2
# 90210  https://p.scdn.co/mp3-preview/8ae49b91c1203b6d...           2
# 90211  https://p.scdn.co/mp3-preview/7201a414b2ee19be...           2
#
#        danceability  energy  key  loudness  speechiness  acousticness  \
# 0             0.522   0.908  4.0    -8.747       0.0596      0.000171
# 1             0.462   0.953  5.0    -6.440       0.1360      0.002810
# 2             0.519   0.607  7.0   -10.636       0.0267      0.001830
# 3             0.640   0.844  4.0    -9.645       0.0539      0.039800
# 4             0.538   0.614  5.0   -10.513       0.1650      0.028000
# ...             ...     ...  ...       ...          ...           ...
# 90207         0.556   0.515  4.0    -5.020       0.0270      0.826000
# 90208         0.524   0.615  5.0    -5.102       0.0287      0.592000
# 90209         0.270   0.575  2.0    -5.736       0.0348      0.511000
# 90210         0.503   0.912  4.0    -4.473       0.0861      0.377000
# 90211         0.567   0.701  1.0    -5.747       0.0430      0.548000
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 0              0.002060     0.458    0.333  118.995     182040.0
# 1              0.000000     0.424    0.269  101.035     145173.0
# 2              0.000003     0.564    0.358  139.950     272973.0
# 3              0.000005     0.122    0.398  106.028     220240.0
# 4              0.005660     0.386    0.559  174.089     222013.0
# ...                 ...       ...      ...      ...          ...
# 90207          0.000000     0.105    0.756   98.142     169590.0
# 90208          0.000000     0.128    0.808  131.141     166620.0
# 90209          0.000002     0.187    0.607  177.269     179690.0
# 90210          0.000000     0.259    0.736  134.795     183023.0
# 90211          0.000000     0.114    0.407  108.388     181003.0
#
# [90212 rows x 14 columns]

# %%
from sklearn.linear_model import Ridge

# %%
np.load(base_dir.joinpath('ret30.test.pred.npy'))
# Out:
# array([9.35514  , 9.119127 , 3.8625977, ..., 8.518085 , 1.7294631,
#        6.1413817], dtype=float32)

# %%
np.load(base_dir.joinpath('test_data','pop.npy'))
# Out:
# array([ 3, 27,  0, ...,  0,  1,  1])
