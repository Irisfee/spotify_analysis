# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import yaml
import pandas as pd
from pathlib import Path
import pickle
from util import save_csv, save_pickle

# %%
util.save_csv
# Out:
# <function util.save_csv(data, fid)>

# %%
class Spotify_query(object):
    def __init__(self, genre):
        # Basic directories
        self.base_dir = Path('.')
        self.data_dir = self.base_dir.joinpath("data")
        self.credential()
        self.genre=genre
        
    def credential(self):
        '''Authorization Code Flow'''
        cred = self.base_dir.joinpath('credential.yaml')
        with open(cred, "r") as f: 
            cred = yaml.load(f, Loader=yaml.CLoader)
        client_credentials_manager = SpotifyClientCredentials(
            client_id = cred['id'],
            client_secret = cred['secret'])
        self.sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
        
    def get_artists_genre(self):
        """
        Query all artists info from a certain genre.
        Save the artist's name, id, followers into a dataframe.
        """
        artist = []
        
        # query the total number of artists
        at = self.sp.search(q='genre:'+self.genre, limit=50, type='artist')['artists']
        print('Total number of artists for '+self.genre+': '+str(at['total']))
        
        # query all artists info
        if at['total']>50:
            for i in range(0,at['total'],50):
                artist+=self.sp.search(q='genre:'+self.genre,limit=50, type='artist', offset=i)['artists']['items']
                
        # create the df of artist id, name, popularity
        artist_df = []
        for i in artist:
            d = {
                'id': i['id'],
                'name': i['name'],
                'followers': i['followers']['total'],
                'at_popularity': i['popularity']
            }
            artist_df.append(d)
        artist_df = pd.DataFrame(artist_df)
        
        # save the artist info
        fid = self.data_dir.joinpath(f'artists_genre-{self.genre}.tsv')
        save_csv(artist_df, fid)
        
        return artist_df
    
    def get_albums_artists(self, artist_df):
        """
        Query all album info from a certain artist.
        Save the artist's name, id, album_id into a dataframe.
        """
        album_df = []
        for index, row in artist_df.iterrows():
            # get all album info of an artist
            album_ar = []
            al = self.sp.artist_albums(row['id'], limit=50)
            print('Total number of albums for '+row['name']+': '+str(al['total']))
            if al['total'] > 50:
                for i in range(0, al['total'], 50):
                    album_ar += self.sp.artist_albums(row['id'], limit=50, offset=i)['items']
            else:
                album_ar += self.sp.artist_albums(row['id'], limit=50)['items']
            # create the df of artist id, album id    
            for i in album_ar:
                d = {
                    'id': row['id'],
                    'name': row['name'],
                    'album_id': i['id']
                }
                album_df.append(d)    
        album_df = pd.DataFrame(album_df)
        # save data
        fid = self.data_dir.joinpath(f'artists_album_genre-{self.genre}.tsv')
        save_csv(album_df, fid)
        
        return album_df
    
    def get_songs_album(self, album_df):
        """
        Query all song basic and audio info from a certain album.
        Save the result into a dataframe.
        """
        song_df = []
        # get song info of each album
        for index, row in album_df.iterrows():
            song_al_df = []

            # get the song ids of each album
            song_al = self.sp.album_tracks(row['album_id'])['items']
            for i in song_al:
                d = {
                    'id': row['id'],
                    'name': row['name'],
                    'album_id': row['id'],
                    'release_date': row['release_date'],
                    'song_id': i['id']
                }
                song_al_df.append(d)
            song_al_df = pd.DataFrame(song_al_df)

            # get the basic info of each song of each album
            tr_al_df = []
            song_id_list = song_al_df['song_id'].to_list()
            tr_al = self.sp.tracks(song_id_list)['tracks']
            for i in tr_al:
                d = {
                    'song_id': i['id'],
                    'popularity': i['popularity']
                }
                tr_al_df.append(d)
            tr_al_df = pd.DataFrame(tr_al_df)

            # get the audio features of each song of each album
            ft_al = self.sp.audio_features(song_id_list)
            # remove potential none item in the list
            ft_al = list(filter(None.__ne__, ft_al))
            if not ft_al:
                ft_al_df = pd.DataFrame({"song_id": song_id_list})
            else:
                ft_al_df = pd.DataFrame(ft_al)[['danceability', 'energy', 'key', 'loudness', 'speechiness',
                   'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'duration_ms']]
                ft_al_df = ft_al_df.rename(columns={"id": "song_id"})

            # merge tables
            song_al_df = song_al_df.merge(tr_al_df, how='left', on='song_id')
            song_al_df = song_al_df.merge(ft_al_df, how='left', on='song_id')
            song_df.append(song_al_df)
            print('Get all songs info of '+row['name']+', '+row['album_id'])
        song_df = pd.concat(song_df)

        fid = self.data_dir.joinpath(f'songs_genre-{self.genre}.pkl')
        save_pickle(song_df, fid)

# %%
spf = Spotify_query(genre = 'mandopop')
artist=spf.get_artists_genre()
# Out:
# Total number of artists for mandopop: 569

# %%
albums = spf.get_albums_artists(artist)
# Out:
# Total number of albums for Jay Chou: 118
# Total number of albums for JJ Lin: 96
# Total number of albums for Eason Chan: 202
# Total number of albums for G.E.M.: 74
# Total number of albums for Eric Chou: 33
# Total number of albums for Jacky Cheung: 245
# Total number of albums for Faye Wong: 145
# Total number of albums for Jolin Tsai: 75
# Total number of albums for Mayday: 123
# Total number of albums for Stefanie Sun: 52
# Total number of albums for Ren Ran: 62
# Total number of albums for Joker Xue: 60
# Total number of albums for Fish Leong: 87
# Total number of albums for Hebe Tien: 69
# Total number of albums for Karen Mok: 173
# Total number of albums for Leehom Wang: 62
# Total number of albums for A-Mei Chang: 73
# Total number of albums for Teresa Teng: 374
# Total number of albums for Mao Buyi: 43
# Total number of albums for Tanya Chua: 51
# Total number of albums for Ronghao Li: 34
# Total number of albums for Andy Lau: 153
# Total number of albums for S.H.E: 82
# Total number of albums for Sandy Lam: 176
# Total number of albums for A-Lin: 74
# Total number of albums for Cyndi Wang: 37
# Total number of albums for LaLa Hsu: 78
# Total number of albums for Jody Chiang: 69
# Total number of albums for Yoga Lin: 82
# Total number of albums for Rainie Yang: 65
# Total number of albums for Sodagreen: 36
# Total number of albums for Silence Wang: 80
# Total number of albums for David Tao: 18
# Total number of albums for Wakin Chau: 201
# Total number of albums for Jeff Chang: 60
# Total number of albums for 告五人: 14
# Total number of albums for Crowd Lu: 40
# Total number of albums for Khalil Fong: 54
# Total number of albums for Angela Chang: 44
# Total number of albums for Wu Bai: 118
# Total number of albums for 高爾宣 OSN: 24
# Total number of albums for Tia Ray: 67
# Total number of albums for Lu Han: 38
# Total number of albums for Hu Xia: 85
# Total number of albums for Jonathan Lee: 131
# Total number of albums for Yisa Yu: 114
# Total number of albums for Jam Hsiao: 79
# Total number of albums for 颜人中: 25
# Total number of albums for By2: 60
# Total number of albums for ØZI: 40
# Total number of albums for Namewee: 75
# Total number of albums for F.I.R.: 43
# Total number of albums for Fei Yu-ching: 67
# Total number of albums for Dave Wong: 77
# Total number of albums for Kelly Chen: 113
# Total number of albums for Joanna Wang: 47
# Total number of albums for Hsiu Chen Chen: 5
# Total number of albums for Elton Lee: 5
# Total number of albums for 水草三重唱: 12
# Total number of albums for 林昭宇: 5
# Total number of albums for 崇喆: 2
# Total number of albums for 高潔萍: 1
# Total number of albums for Bonnie Loo: 11
# Total number of albums for 吳慶康: 5
# Total number of albums for 謝慧嫻: 7
# Total number of albums for 湯薇恩: 6
# Total number of albums for 洪劭軒: 10
# Total number of albums for 陳美心: 1
# Total number of albums for Nana Lee: 3
# Total number of albums for 颜黎明: 12
# Total number of albums for 10vacations: 2
# Total number of albums for Hagen Troy: 3
# Total number of albums for 張小英: 2

# %% [markdown]
# Questions:
# What audio features contribute most for a successful artist in mandopop?
# 1. Overall popularity defined by followers
# 2. Overall audio features change over years
# 3. SVR analysis of each feature

# %%
song_df = []
# get song info of each album
for index, row in album_df.iterrows():
    song_al_df = []
    
    # get the song ids of each album
    song_al = sp.album_tracks(row['album_id'])['items']
    for i in song_al:
        d = {
            'id': row['id'],
            'name': row['name'],
            'album_id': row['id'],
            'song_id': i['id']
        }
        song_al_df.append(d)
    song_al_df = pd.DataFrame(song_al_df)
    
    # get the basic info of each song of each album
    tr_al_df = []
    song_id_list = song_al_df['song_id'].to_list()
    tr_al = sp.tracks(song_id_list)['tracks']
    for i in tr_al:
        d = {
            'song_id': i['id'],
            'popularity': i['popularity']
        }
        tr_al_df.append(d)
    tr_al_df = pd.DataFrame(tr_al_df)
    
    # get the audio features of each song of each album
    ft_al = sp.audio_features(song_id_list)
    # remove potential none item in the list
    ft_al = list(filter(None.__ne__, ft_al))
    if not ft_al:
        ft_al_df = pd.DataFrame({"song_id": song_id_list})
    else:
        ft_al_df = pd.DataFrame(ft_al)[['danceability', 'energy', 'key', 'loudness', 'speechiness',
           'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'duration_ms']]
        ft_al_df = ft_al_df.rename(columns={"id": "song_id"})
    
    # merge tables
    song_al_df = song_al_df.merge(tr_al_df, how='left', on='song_id')
    song_al_df = song_al_df.merge(ft_al_df, how='left', on='song_id')
    song_df.append(song_al_df)
    print('Get all songs info of '+row['name']+', '+row['album_id'])
song_df = pd.concat(song_af)

fid = data_dir.joinpath(f'songs_genre-{genre}.pkl')
save_pickle(song_df, fid)
# Out:
# Get all songs info of Jay Chou, 5lqE2qT3nGLW6FGoJYfwUT
# Get all songs info of Jay Chou, 3mqG5FjCm7XuCx5IHN3ZSg
# Get all songs info of Jay Chou, 5clrYp291Dg0XL6rgvOgoB
# Get all songs info of Jay Chou, 0ByfRfYXHHhGjsXEabfDmf
# Get all songs info of Jay Chou, 35nLe33atE2S9Oo4fBRWll
# Get all songs info of Jay Chou, 0AMaK4fzYnhvi4HTNVvKet
# Get all songs info of Jay Chou, 1aYDr6muZPmwYvstDnIbeH
# Get all songs info of Jay Chou, 1TN7aPDawSKY2yJgGRuBtD
# Get all songs info of Jay Chou, 2afPHXn7m4KQECRsVn41us
# Get all songs info of Jay Chou, 2mfQMCY9GF34zQ8bqhIrmQ
# Get all songs info of Jay Chou, 5Ld4kLIL16CwUAx7IbxtIQ
# Get all songs info of JJ Lin, 6EoLd0I5RKh4ZI7906Fcmt
# Get all songs info of Eason Chan, 23aP7DPqQDVrAS7ewQTBOG
# Get all songs info of Eason Chan, 0uHFrmaLLpx6x5wDMKCqKb
# Get all songs info of Eason Chan, 7edjjiz1JlTXwZL6Z8r0Q9
# Get all songs info of Eason Chan, 3otpS2Fknqraz3hMbgRfOr
# Get all songs info of Eason Chan, 6zJUFONywc06m215HRHKxi
# Get all songs info of Eason Chan, 0mZyw7Kjftvwr4Vs1fiOhy
# Get all songs info of Eason Chan, 0wWuBzOyOFxzfSPr9HSehB
# Get all songs info of Eason Chan, 1i1ISMhespmATpxL9x7yOR
# Get all songs info of Eason Chan, 1AzEJfSldVxGojEqAPPOyC
# Get all songs info of Eason Chan, 6mPxcfXiWZ2lOUeAokuYnE
# Get all songs info of Eason Chan, 1QTcEYZJttVzQ4nWGkITTA
# Get all songs info of Eason Chan, 4vS7uFNBVdu1TFWWDHjZ7E
# Get all songs info of Eason Chan, 4cfO1Y2sdhnzFdE1Ix81BZ
# Get all songs info of Eason Chan, 08Bdvah5BgcjmxWymrV9Bl
# Get all songs info of Eason Chan, 3hYNHvbd1Q3AhB5K53ymNm
# Get all songs info of Eason Chan, 32HBZDmhLuK8eJRWd58jZN
# Get all songs info of Eason Chan, 38Z2zxJJaD0OMhbMRUdbuy
# Get all songs info of Eason Chan, 07fbAm4G10mTHjzWk8pz62
# Get all songs info of Eason Chan, 3lDi5sOZSO7iuFUq5ZHgtW
# Get all songs info of Eason Chan, 4tPgavx8TzhK03utfMCgHL
# Get all songs info of Eason Chan, 7Bk96bkNJKHtUmTuzN364p
# Get all songs info of Eason Chan, 5dVoncJu7uOW9zlMSt7oQK
# Get all songs info of Eason Chan, 0e46RtuuQuKUHqxn9OdJX4
# Get all songs info of Eason Chan, 75Z4mycQCI9H6OI08G3HOi
# Get all songs info of Eason Chan, 59jGSVMqMFbUbTdrrzx91W
# Get all songs info of Eason Chan, 6Gg3QFdnegEa9lUDKtbZ9K
# Get all songs info of Eason Chan, 0PME3uo5X693GVtg9LGZ19
# Get all songs info of Eason Chan, 4KnIbucnL2Ujzc5vP4DawA
# Get all songs info of Eason Chan, 5HE42EBiYFwP9tqzqJ3cWt
# Get all songs info of Eason Chan, 7r59TYLpvEeRRmdyXT8Hxw
# Get all songs info of Eason Chan, 0o999KbXQDQREsY9VLerc5
# Get all songs info of Eason Chan, 2CKvwKuHcZvnt4mC9DB6Fk
# Get all songs info of Eason Chan, 28EFqQxFk44OXnmbVaOHEn
# Get all songs info of Eason Chan, 1dtg7IOdq2Q6zA4nIJ5Qsk
# Get all songs info of Eason Chan, 2q8B5oKXxWEbtjQwdpwEyW
# Get all songs info of Eason Chan, 3NroP8rfxCPA60CaNFz1kb
# Get all songs info of Eason Chan, 3Y1KyBOAPB5CpPEWAIxbgB
# Get all songs info of Eason Chan, 29iUKNsSihTdmAwUPdgkrt
# Get all songs info of Eason Chan, 7EoNZqWSwbgr55td5Z7hxT
# Get all songs info of Eason Chan, 1GZpD5IdcUfWZPwVFYO9YM
# Get all songs info of Eason Chan, 0zMV4uDNTSQAiphN3cVzQ0
# Get all songs info of Eason Chan, 5C25RsjgCdE1q7vpJcXt8I
# Get all songs info of Eason Chan, 1YhlJrqnaO8Ks2AwvOuVgE
# Get all songs info of Eason Chan, 2DNIE0pIa9LqSKjzDPN01n
# Get all songs info of Eason Chan, 28bO3TMjA3mtQwnk8MPYrE
# Get all songs info of Eason Chan, 7IWCQYu2Tz27p3BCcKt1PL
# Get all songs info of Eason Chan, 62uFEXorvZSDzdV1PNKyVM
# Get all songs info of Eason Chan, 0gun3Wf4rgYljgCXjz7PY7
# Get all songs info of Eason Chan, 3e6hsNpk7KOF22etiA80tM
# Get all songs info of Eason Chan, 6HsDj5Zdpd7Xhgl4X0vVT5
# Get all songs info of Eason Chan, 4Xp7Lnlp7Ml2X0MSEXzxb4
# Get all songs info of Eason Chan, 53PqAixCRgAgchN5ZCcylL
# Get all songs info of Eason Chan, 1GXTBT5hlg7AJ2XPMl3Qbf
# Get all songs info of Eason Chan, 3dEDNU4WR0RZskOUR7ureC
# Get all songs info of Eason Chan, 3F2CBQTEqTGndLaXXVbbgi
# Get all songs info of Eason Chan, 4gmeqm0rqoy5YLMaT1qCwF
# Get all songs info of Eason Chan, 2R9j6chH2WczYgHTbG0FQx
# Get all songs info of Eason Chan, 2fh9N8ZiXMe3S93vqzJxgp
# Get all songs info of Eason Chan, 3yElXDCHBTkx7eGIIKv0fp
# Get all songs info of Eason Chan, 0ISWn1TEdMzuIHdZTXL8rr
# Get all songs info of Eason Chan, 1KJSICwR3yrNqkXDs3s2MN
# Get all songs info of Eason Chan, 6r8VtnDDnXoy179XaHHwKe
# Get all songs info of Eason Chan, 2R1nnaw5zJ5xv91GVW71XX
# Get all songs info of Eason Chan, 7zobMuewVIQTaKHBpbExEz
# Get all songs info of Eason Chan, 7ADUNbwX01zsC4EOvRlvV3
# Get all songs info of Eason Chan, 7JpJ5Xnpygi1mvnb0zFSNE
# Get all songs info of Eason Chan, 31Hq9xhKYFEKsaCeZ1my7r
# Get all songs info of Eason Chan, 3QQtXTVbQ6l3kbjZGjgPmE
# Get all songs info of Eason Chan, 55Ro04UwGKHwUZ5nC3rr2r
# Get all songs info of Eason Chan, 6zYEDw4Rgt1jwVXcYk7Snu
# Get all songs info of Eason Chan, 6K68GJwJ7qbqfPLG4yKzGk
# Get all songs info of Eason Chan, 1ReoQgQaUzIfCRgPU4b9vq
# Get all songs info of Eason Chan, 0X9sclpjJmYpM1codmsJYk
# Get all songs info of Eason Chan, 6IsyiW0d4ZU1oWHA4SSUHL
# Get all songs info of Eason Chan, 1ACVq3xyyXV3ITt8ptj6b7
# Get all songs info of Eason Chan, 0f3fXdmKfX0cDRweUH37e7
# Get all songs info of Eason Chan, 4VNcjbvxoown8zhnXUSuVy
# Get all songs info of Eason Chan, 2fSSmhfFGpui0YAZaQgMWt
# Get all songs info of Eason Chan, 67vVgPVhd9sDpTQaWVf2BG
# Get all songs info of Eason Chan, 4ArH4Tbqjz16Ut1cB5gtd5
# Get all songs info of Eason Chan, 1vVkppQPG1vbkmoNjoAFzA
# Get all songs info of Eason Chan, 5gK3jWP8EnZFJurmHnWEit
# Get all songs info of Eason Chan, 6N5hENxwRvib6xPuUWjSgi
# Get all songs info of Eason Chan, 1NgBgqGC4JBy1SXWaOvUiZ
# Get all songs info of Eason Chan, 12PH9dLo67E1lnORMYyNJX
# Get all songs info of Eason Chan, 1upKt8KcaPzHWseWf5gClX
# Get all songs info of Eason Chan, 5nFbcARaMC2MhVzdpltINk
# Get all songs info of Eason Chan, 3gesCPIS0wINVUE3I1NyCr
# Get all songs info of Eason Chan, 63pw0hKVhLZQPdLOWko3Xu
# Get all songs info of Eason Chan, 30vxdcGFJcI7hPXgxRVoLi
# Get all songs info of Eason Chan, 3s3iFfZEhgsGbSb7AzZTaE
# Get all songs info of Eason Chan, 4RMq0Nd5JkwXNkSn5RpaHG
# Get all songs info of Eason Chan, 5RUQ9WVy6EZQbEFWPwCBTj
# Get all songs info of Eason Chan, 3tqoZPLhbWfFWisaHGKY64
# Get all songs info of Eason Chan, 4TezJaKpqA6biv06sLbL4G
# Get all songs info of Eason Chan, 0ebzpPW8pQHp7yRbSnNfge
# Get all songs info of Eason Chan, 04JYAqplo90SJeXOPA4D78
# Get all songs info of Eason Chan, 2VD034FpZo6JRtBvJuHsfT
# Get all songs info of Eason Chan, 2P5Yu1puVm2EQruOpZK3xw
# Get all songs info of Eason Chan, 11VVLl3BrFnuDSJTJG49gG
# Get all songs info of Eason Chan, 3OqP4xLC5FnRaoQUYtdlem
# Get all songs info of Eason Chan, 6FUPMWiRQWJO2mcV1APGR3
# Get all songs info of Eason Chan, 5YTf9MlTnLTbdf0KbYnw1D
# Get all songs info of Eason Chan, 1h5Vo4A42rlb10SZjpYDAP
# Get all songs info of Eason Chan, 35ACOuzOdtR5OUdwTRWfu8
# Get all songs info of Eason Chan, 1ym1laG5jyfzGNDn7WRBA1
# Get all songs info of Eason Chan, 5uoyN8e3QP37fjwdASDFih
# Get all songs info of Eason Chan, 6Z1pu2Zg8BfwLCxvMTpLdw
# Get all songs info of Eason Chan, 7E3NzJu0rkM1NHeaRpWlOE
# Get all songs info of Eason Chan, 7lTI7uiOEGhzWYpoVpHlgi
# Get all songs info of Eason Chan, 2mBGFraGTf6qWKmRb4YL8l
# Get all songs info of Eason Chan, 5rmOGd5jQ5ZrriWneq51xg
# Get all songs info of Eason Chan, 63P6CulP5SGuXywInt8MKH
# Get all songs info of Eason Chan, 4if9UqM16jFieJ6LIbeG0r
# Get all songs info of Eason Chan, 2nVl3INmuyP9VZvEU3rFZu
# Get all songs info of Eason Chan, 0LrkMelJbhXwgvs4WUKlvL
# Get all songs info of Eason Chan, 2eh9QfzHqbIKvPSZR1lCzn
# Get all songs info of Eason Chan, 0OGKReicGspA6k3fZLz1Ei
# Get all songs info of Eason Chan, 1rdp4FLJYHoR6mH1fCcAJV
# Get all songs info of Eason Chan, 2myQu1HIOUrkF7oPUA2Xzp
# Get all songs info of Eason Chan, 5gqmD2ZDAUogbJ2McfE492
# Get all songs info of Eason Chan, 3tjg0ktumPOoewlyYnE14D
# Get all songs info of G.E.M., 5BQmFN38iOhEhMVIdtvFhS
# Get all songs info of G.E.M., 1tEl9cDFkTKGmaRpZLB7zW
# Get all songs info of G.E.M., 0dAaNCZ8zt38pv5VJ2yHcM
# Get all songs info of G.E.M., 5EUhTGmsSlrrt2w3IZd1IG
# Get all songs info of G.E.M., 2ZkF6zANeekBDgwMFGLIlf
# Get all songs info of G.E.M., 4uUQ8WSaEXwrjC3b0gKt58
# Get all songs info of G.E.M., 2hpeqJZrqiu2PnyejetReH
# Get all songs info of G.E.M., 2d7GxLlPqbUD7FNOlyrBXR
# Get all songs info of G.E.M., 4A9sWkn6DR7E6wXNx2Tibu
# Get all songs info of G.E.M., 6dOrr1HwvFh5vg1PKP4z4K
# Get all songs info of G.E.M., 0lbzpMHImMAJFXlG51JHej
# Get all songs info of G.E.M., 4NpzkFA3Pkdntw0PG7kctp
# Get all songs info of G.E.M., 0C0U1OAzhWx9PELsvFKSqG
# Get all songs info of G.E.M., 1FEbYK8065NE897RuDeHI2
# Get all songs info of G.E.M., 6ZKNsSx0wxYslBFCiP6pt6
# Get all songs info of G.E.M., 28sxY4WxuFLQ5wMeugtyAp
# Get all songs info of G.E.M., 0aywTq3TUa7QQDD98jcSGF
# Get all songs info of G.E.M., 44IRnm2xifdB0C9oLyVT8b
# Get all songs info of G.E.M., 3V4IPAepNU16KAzbUjGnkx
# Get all songs info of G.E.M., 6zAtcPh8OWSirv5j43vKGA
# Get all songs info of G.E.M., 71fPQnHQ6HZ85qBuWT1zmm
# Get all songs info of G.E.M., 4vLAKoHvI3xgMV3SuNEXUV
# Get all songs info of G.E.M., 0ki23O83ZWMVpxYOSv5bb5
# Get all songs info of G.E.M., 5tiWzEgxHiddFZUt5Swfzg
# Get all songs info of G.E.M., 7b2UFbCnYH3ABboT4V9Zta
# Get all songs info of G.E.M., 7qIS9DA7elqcOc7V3t8Iqs
# Get all songs info of G.E.M., 4Kp2j86QXBJLz9WgTm7K56
# Get all songs info of G.E.M., 2TbOZMhNGtiU7JIF0SHBmK
# Get all songs info of G.E.M., 3jOrD4SYj8meiZ3blwuxRg
# Get all songs info of G.E.M., 4Rj45hFC3cH5N4cq8mutDF
# Get all songs info of G.E.M., 4eQDYF5DRwKtOCidoSe9HP
# Get all songs info of G.E.M., 60RgsKk9GghQyzgo1ilYoa
# Get all songs info of G.E.M., 7h4jhOf1kpyyoMZGUanC2v
# Get all songs info of G.E.M., 0JUutLFNaI5co8iyZiOYTi
# Get all songs info of G.E.M., 4UeZkzpaXZiYUXsxhzTneV
# Get all songs info of G.E.M., 7fVVLWSX7VyAPOqdV3zln8
# Get all songs info of G.E.M., 6vIWcOgbG5nw2Yy6kwAqiI
# Get all songs info of G.E.M., 4UmTf0Qp8CGeV6TpRNE6lT
# Get all songs info of G.E.M., 3meNXACNkJFzY4Etrhb9H8
# Get all songs info of G.E.M., 60Q9EvEL86bt1hFwZCqQOR
# Get all songs info of G.E.M., 31AP0Tq3uqJMZPwqydMvEx
# Get all songs info of G.E.M., 2I04Ny6Rm09PEWXgFdnElx
# Get all songs info of G.E.M., 7CC4NE0NadC4rD5jSEQWLL
# Get all songs info of G.E.M., 0QrClovQcZEdV7Cf7ownO6
# Get all songs info of G.E.M., 6zZe6euXprzLGDiGwF53LC
# Get all songs info of G.E.M., 1oC5obajNGgZ5MMsPbURiV
# Get all songs info of G.E.M., 6dQXxY3WS3lcKVCqORfrgw
# Get all songs info of G.E.M., 2gXwK6hARFzsiELwcOsvY7
# Get all songs info of G.E.M., 1pX0KEJdCTAGQ1NzSKRkNt
# Get all songs info of G.E.M., 7Afs8v9NJU8mtfXRH4MLFY
# Get all songs info of G.E.M., 1VtgUZpWRP9WLiK0WjvTZ7
# Get all songs info of G.E.M., 6XQhiXvWRqoUeKbiv6OpXd
# Get all songs info of G.E.M., 4dE8svIbY8hk8VRtIqT1FI
# Get all songs info of G.E.M., 3gLFJ6ceqI5Z9OuALQ6VQw
# Get all songs info of G.E.M., 0tRwZeTgg0gsMN67usxsGF
# Get all songs info of G.E.M., 3n8835yAbjAdQS99ov3FjI
# Get all songs info of G.E.M., 0oP2dGdz1DOparg7bayI8Y
# Get all songs info of G.E.M., 4rWDXw6x6eAaaCbjNjmM9e
# Get all songs info of G.E.M., 5lGdgVzbI73QHouIJnu0tX
# Get all songs info of G.E.M., 3fSML6UB7zI59Cr7mswQHt
# Get all songs info of G.E.M., 3e6IBDz5nqAuvg0AEjpjPX
# Get all songs info of G.E.M., 2LokHqCckCXxxm2wLhhJSM
# Get all songs info of G.E.M., 4O8UFP6RVqocxjHx8qhTnc
# Get all songs info of G.E.M., 7yPerXuTprbSRaXGq5xc0a
# Get all songs info of G.E.M., 3CHQ4axtQCXt2LoqJA3ViE
# Get all songs info of G.E.M., 202VMRI3uuqDwBh5PgLqfn
# Get all songs info of G.E.M., 1qZYLUauV5hDgI5HBlLqz9
# Get all songs info of G.E.M., 6fQWn6AMg9PYShzE7b7awn
# Get all songs info of G.E.M., 4fHoyOJIgwB3j9GDy3CF3F
# Get all songs info of G.E.M., 4kXABOKrhJ2jKUNYGRQPr8
# Get all songs info of G.E.M., 1TBdVHWbeWlYvt6ZvGfdOG
# Get all songs info of G.E.M., 7A6kUu6jYulPsmCOvwJZZ7
# Get all songs info of G.E.M., 0ZXRc3YnvRu4DeAKbtzCT0
# Get all songs info of G.E.M., 1GknFLF7hAN7thhuKzQfx6
# Get all songs info of Eric Chou, 2GaVDyAX5sgrX5CuWxRhZm
# Get all songs info of Eric Chou, 2lrmHLTedOpdP6TaZDZ77F
# Get all songs info of Eric Chou, 63lCCebNDe20nxyCvFWk8g
# Get all songs info of Eric Chou, 6UNR1S4FPnivCfBvwb1amv
# Get all songs info of Eric Chou, 4qDKkkL98yqdv85xqYfyUc
# Get all songs info of Jacky Cheung, 7k1QxIQTHPkzwsh6dI99rO
# Get all songs info of Jacky Cheung, 6C6myxCMDNokbCAogRYNA0
# Get all songs info of Jacky Cheung, 4malY3iZAnMCdTUVnVnKiJ
# Get all songs info of Jacky Cheung, 72IBaCd5VrDho1jzJHsxga
# Get all songs info of Jacky Cheung, 4fVbdoGVFrwpsfRlXj3h4C
# Get all songs info of Jacky Cheung, 5LM5Xcf8vRmyoRF6uq6g2a
# Get all songs info of Jacky Cheung, 2FrulM7NZvVtTTkyIyjuKj
# Get all songs info of Jacky Cheung, 1dJJGScWjMBwdOOnit9umL
# Get all songs info of Jacky Cheung, 7AU0qSQaxlrpDxu82JjwEC
# Get all songs info of Jacky Cheung, 1kpYHLxATPVPNwzb0NeYe0
# Get all songs info of Jacky Cheung, 638h6Jjo6BtVm6vOJKjFbJ
# Get all songs info of Jacky Cheung, 2Nx9HE6sWJo75AhE8mZSzO
# Get all songs info of Jacky Cheung, 4mRLdxnIEzfSifdb7gzwP7
# Get all songs info of Jacky Cheung, 1a030atlYsgFZhxAvwOuM2
# Get all songs info of Jacky Cheung, 0FOYCSPRz8rHTYgQphBLrS
# Get all songs info of Jacky Cheung, 1NdBFglx7wopVSRoHmZ8KT
# Get all songs info of Jacky Cheung, 1ghicsbD7FXxS25N8VGcKi
# Get all songs info of Jacky Cheung, 0QL36FG58sV9suZsbDGVqm
# Get all songs info of Jacky Cheung, 60jGgKxGQPMIh1zwby5yZT
# Get all songs info of Jacky Cheung, 7KqKkd5PipTNnPSGd7OT6r
# Get all songs info of Jacky Cheung, 4xSe08zybd3wEfe2f0azf8
# Get all songs info of Jacky Cheung, 5qYIS1bv4ABLAPiTKBUDZS
# Get all songs info of Jacky Cheung, 0WpcnKMjK0ovshd1NLiJvp
# Get all songs info of Jacky Cheung, 24RV9wssljOpR7Xaps3KJO
# Get all songs info of Jacky Cheung, 3oNbVIRW19jzrIFRP0K0TP
# Get all songs info of Jacky Cheung, 4MkS9FiDOZ2UtFmisxaseb
# Get all songs info of Jacky Cheung, 4zdXEC8c1qobHPiFiiWHZj
# Get all songs info of Jacky Cheung, 2syeeXXUlxZ1c1kSjkJd7M
# Get all songs info of Jacky Cheung, 6qZsVoRRMcPh88XPS7hdcW
# Get all songs info of Jacky Cheung, 5FhKi7rkSdgJhQeNEmNPje
# Get all songs info of Jacky Cheung, 5njJpXTyduPYO18rcY1UdC
# Get all songs info of Jacky Cheung, 7DBpn0Qji0bjj3zX0d6pMH
# Get all songs info of Jacky Cheung, 5XDWSX0O2RkbfZyqva7JSc
# Get all songs info of Jacky Cheung, 6GdK7WRz8gwW4nTH4NdQKu
# Get all songs info of Jacky Cheung, 72BEqChxgUlDKReFxEq2Xp
# Get all songs info of Jacky Cheung, 0wz5K79iEyDFxvMQkZJMXe
# Get all songs info of Jacky Cheung, 45laSRqRIxlUOFAF5Q1k8v
# Get all songs info of Jacky Cheung, 740peQCOLgxJuKxjcmmx4h
# Get all songs info of Jacky Cheung, 7FHnxIei0uMHzTl02XjX2E
# Get all songs info of Faye Wong, 3GdS1D28z3Qn2fJ6iXR9jt
# Get all songs info of Faye Wong, 3zu182oN49SiaJ5amdF1Em
# Get all songs info of Faye Wong, 2RaCCh4fU2cdMakSGNFGgZ
# Get all songs info of Faye Wong, 6XB23e46qci9k5jSZG2k5D
# ...
# Get all songs info of Tangerine Wong, 13JpgLyP8ZDyAtsRllAaGe
# Get all songs info of Tangerine Wong, 1W6bUT0YqOG5pcPfOUT7V0
# Get all songs info of 李千那, 5H60MWb7e5s9WHmgPvaiHN
# Get all songs info of 李千那, 4dmchdsgAGoNdEeZTXL4OT
# Get all songs info of 李千那, 3ZDvcq25rw1tGzChPSco4F
# Get all songs info of 李千那, 0eXMhgxKpq65V4NVa852Qq
# Get all songs info of 李千那, 1zEK0yYTWRgsudA2NxWKwy
# Get all songs info of 李千那, 6cmfWMoPzvzQe89VLRIXke
# Get all songs info of 李千那, 745P1JFRgjfucgikEjCxDR
# Get all songs info of 李千那, 2tZlm0XkhD1Hix6kbRNfB1
# Get all songs info of 李千那, 23obovBNEB1lxORo8oR5yn
# Get all songs info of 李千那, 7GL1d0RDsArwCJYttz9lSu
# Get all songs info of 李千那, 24UlFtT3ENIde6nkVBJRov
# Get all songs info of 李千那, 5rNZpq4CpR0n5X5oeK82GW
# Get all songs info of 李千那, 0vgUgTsSOi4PETtBkHYoX2
# Get all songs info of 李千那, 5BCwiN0uKE2OAl8cxVPMDy
# Get all songs info of 李千那, 3WCP9gdwcON7Z9d7dKrI9s
# Get all songs info of 李千那, 41UCrgW5HU8QJSG3wJFopX
# Get all songs info of 李千那, 5gEEjjBM0xcKf5MKezZGhW
# Get all songs info of 李千那, 4RY0eYoGDjDWNcTgExxWeI
# Get all songs info of 李千那, 0TIFDreUwnmXcjN6Hf211G
# Get all songs info of 李千那, 62wAb9EP1nfIR9yIDgwfmV
# Get all songs info of Z-Chen, 5gh44X4smbGBynxQdAWag1
# Get all songs info of Z-Chen, 7Bj6XPvfBOTCqzggEsKiHE
# Get all songs info of Z-Chen, 7bLchgVymBOqH1tAX9V9Xe
# Get all songs info of Z-Chen, 1rnc6XQcWjgZnNW4WIO61J
# Get all songs info of Z-Chen, 2jWwlTFQ3XfbyZdgmFQaYw
# Get all songs info of Z-Chen, 3K9mY6cKbDMC7jW9NRWPJ5
# Get all songs info of Z-Chen, 09qN62Ou0rgEcc8H9I2OwH
# Get all songs info of Z-Chen, 1cyKUi5zRoSpnRaKSY29iu
# Get all songs info of Z-Chen, 3lvWfI48D8tQFdT1civZsB
# Get all songs info of Z-Chen, 1hFWZmvdhOtcZ71Rtp8SlH
# Get all songs info of Z-Chen, 57ienfagA0GKFEKj9e2jt0
# Get all songs info of Z-Chen, 00ERv5lKfFKlyAiCSPC1F7
# Get all songs info of Z-Chen, 49cLlkZDETmetG6MpYe4Xk
# Get all songs info of Z-Chen, 7xMnXYqwt3PbD1xR7mkv9G
# Get all songs info of Z-Chen, 4KAjY1gRKHLkHXEKDIzGiG
# Get all songs info of Z-Chen, 4D4NC5uuvuZcmzZa5OCV6b
# Get all songs info of Z-Chen, 6DJzoVYJRFOSoAEZgGxiE9
# Get all songs info of Z-Chen, 0z883k1plljEj5fZYvIkUd
# Get all songs info of Z-Chen, 6WB7YeSBTQKhMcFH0tmmnq
# Get all songs info of Z-Chen, 68EDOO8VJFkW2SCfzhJ69G
# Get all songs info of Z-Chen, 3cmxDTkc3ws9Hct7ZVzPcx
# Get all songs info of Z-Chen, 6Hylig6zToi4QuuvWxpy20
# Get all songs info of Z-Chen, 7vfsCy9xvMiZpATGGRsimA
# Get all songs info of Z-Chen, 0JlplmyG1j6Nq4Uud8Xy4H
# Get all songs info of Z-Chen, 5sDdZwMedtgDerMwAlnxZJ
# Get all songs info of Z-Chen, 79RVoXUiYqAjGcBJ5Y7Tx0
# Get all songs info of Z-Chen, 4cnN8kCS52KBUv6sDcLfV2
# Get all songs info of Z-Chen, 2czIFONVZmrwYMhp6JZtjC
# Get all songs info of Z-Chen, 0YpuMdQ4j3yr6cenA3Ozfl
# Get all songs info of Z-Chen, 1jUs1uNVTmY3W3NOiempbv
# Get all songs info of Z-Chen, 5upqYDiSecuLd8SWRCFyC4
# Get all songs info of Z-Chen, 34ZkKFd3nYf7zy1YqXQQUg
# Get all songs info of Z-Chen, 394hiKQuwyUGN2SgYlZjma
# Get all songs info of Z-Chen, 2WW7f03fQXLyeAp7gJ4Bbj
# Get all songs info of Z-Chen, 72FjNBGhKYNrAbzFTGsO87
# Get all songs info of Z-Chen, 4igR2pywOUPBKNx2ljz1bw
# Get all songs info of Z-Chen, 5so8XDk8RBoxbH4pVTpVPh
# Get all songs info of 林隆璇, 5xoODubNO0hJQyJtXuh5rV
# Get all songs info of 林隆璇, 2zSh5E240HvZyvcU5N8ux1
# Get all songs info of 林隆璇, 1qVjSg1IHuuhRUM6m8I944
# Get all songs info of 林隆璇, 0RaM93MqFHiep5AgXvdBv6
# Get all songs info of 林隆璇, 4hrW4Z923E1RLRq9NARwCl
# Get all songs info of 林隆璇, 4WVW2QKE3m2ILe26w3K0IA
# Get all songs info of 林隆璇, 7jw9edcJB7KrdndeIr9E4E
# Get all songs info of 林隆璇, 0tF69PK9UPkmvhlJY0iNmX
# Get all songs info of 林隆璇, 1Ee3JFMO79h37QlXmg2IYt
# Get all songs info of 林隆璇, 1yiGLfGgExl4JvA6UrfUeM
# Get all songs info of 林隆璇, 2voP2EdbyQd7bWh1xKMJ2U
# Get all songs info of 林隆璇, 43M5dKYVJPW1tSzSt3lwa8
# Get all songs info of 林隆璇, 1sksZWC7H9Dzd5fYgiDUqM
# Get all songs info of 林隆璇, 6vAJR7KV4HZffOoK4FWzVn
# Get all songs info of 林隆璇, 09U0jYrhcxqfP0X62Ke5mW
# Get all songs info of 林隆璇, 5mOXNTFAnZBhyRNrmj3fo4
# Get all songs info of 林隆璇, 05pijaJQdUwPass37Q7yCQ
# Get all songs info of 林隆璇, 2Ms9E71D1o2COEQriXuVDj
# Get all songs info of 林隆璇, 32vQiY37nP053liBmwvzNi
# Get all songs info of 林隆璇, 1q9wPTdAGW5P1qct2iAj2z
# Get all songs info of 林隆璇, 4EMHto0ArB4tyb5vFwkz6m
# Get all songs info of 林隆璇, 0nsjUFugE1A79BtUzKNyAH
# Get all songs info of 林隆璇, 5PEV8b1ZuWB2uBkPEkO9aJ
# Get all songs info of 林隆璇, 5DYLR1esjGFGr8iNdEeoCv
# Get all songs info of 林隆璇, 3c7WxXXj2PXqyHZ2HN1dFz
# Get all songs info of 林隆璇, 6XB23e46qci9k5jSZG2k5D
# Get all songs info of 林隆璇, 68PjJHVQeRLzAIsEqXOkeE
# Get all songs info of 林隆璇, 59ZK9vUwVUA4b19rNibdGB
# Get all songs info of 林隆璇, 3Z256rjIJDjHcng7TX5DJL
# Get all songs info of 林隆璇, 3d5yWXB9pc9g6Y06i8m12B
# Get all songs info of 林隆璇, 78wGJvA0QP9zHv4wpTPgUg
# Get all songs info of 林隆璇, 6WGtQhmOm0PSMdadOwFhUw
# Get all songs info of 林隆璇, 5usgLFsWNH4YzmOgY4oS2W
# Get all songs info of 林隆璇, 2tLR3cO8m8HRK1E669DRYc
# Get all songs info of 林隆璇, 07lLdqCPxntFSrWwHOvORg
# Get all songs info of 林隆璇, 2XOWSNWLdeC1MBak8ctmXG
# Get all songs info of 林隆璇, 3fMpFLlmgJMOkVJbbuh6j9
# Get all songs info of 林隆璇, 5dCIodIxt2xponahq4bIaX
# Get all songs info of 林隆璇, 4zdXEC8c1qobHPiFiiWHZj
# Get all songs info of 林隆璇, 3V9AfCPfoiqcgU6oEcYfGd
# Get all songs info of 林隆璇, 4UvLcOiXqqNcmPcrpPQGJw
# Get all songs info of 林隆璇, 10csYVHw2fDonEJAXbIwpk
# Get all songs info of 林隆璇, 44JpuajGnjnfbV1Df2ELBw
# Get all songs info of 張洪量, 2PUf5cAXkzMp9FaAhg4jZ9
# Get all songs info of 張洪量, 0y5MO8TOSpxaOMPoxfu3e5
# Get all songs info of 張洪量, 4Xt83VzllJzkoGnpXPV4f9
# Get all songs info of 張洪量, 6xzp0PapUiGqgHid9DXEfS
# Get all songs info of 張洪量, 1lyjs1UFoqNrkdtWQ3UexT
# Get all songs info of 張洪量, 2anFP1oQwDMy4D2f06gYXw
# Get all songs info of 張洪量, 3RaBIIRQ4yNw4eQTsIppe7
# Get all songs info of 張洪量, 18FVasqDD3JYkLO6JeafPx
# Get all songs info of 張洪量, 15fbsedIdXNaQQJWnfz1r1
# Get all songs info of 張洪量, 6q0eGEnPFQvCYgpGJtEwtQ
# Get all songs info of 張洪量, 79jFnfjkPhqGB0j4vIiWwN
# Get all songs info of 張洪量, 13w8GujoFBzqXuEj3Li424
# Get all songs info of 張洪量, 5xF9EBXrLl7ASPmdSV1yjF
# Get all songs info of 張洪量, 1ZlDBRcJ5Aeas9ToCdVLc0
# Get all songs info of 張洪量, 0Qw9a4cmOoL2tRPGuRDhQT
# Get all songs info of 張洪量, 5RosboSMMZyEPa3qkenEdP
# Get all songs info of 張洪量, 24707scowRu3CaQ6d0U3SD
# Get all songs info of 張洪量, 0e4bGMrU9WmApKZMuyI4XH
# Get all songs info of 張洪量, 2RAO5vtl8fY4Hy1k2bbLj4
# Get all songs info of 張洪量, 4hsKUtP2exyG6EEQG9grCe
# Get all songs info of 張洪量, 7LKM35Qv0JPEqNHlx3ouuR
# Get all songs info of 張洪量, 0cPojvA2cqqWrzzCi3i2dh
# Get all songs info of 張洪量, 0VUNkIT22qx8BGMeBlJECM
# Get all songs info of 張洪量, 4G3tX2nbaTVLwUVZXcvi0H
# Get all songs info of 張洪量, 4B2ju31Cx8eq4Ifo0pvr3C
# Get all songs info of 張洪量, 5dmPS0KJQn8LxYgUnmNLyR
# Get all songs info of 張洪量, 6hIiBtX8NAKn0T6cvNwvi7
# Get all songs info of 張洪量, 297ypR1bzfkQuDWkyC4NXb
# Get all songs info of 張洪量, 2IK0ZeRBeKTIQtOw3OgMKU
# Get all songs info of 張洪量, 44avwxu2SO4S2OXxux1CMp
# Get all songs info of 張洪量, 6Ot6BdlWZta7SeiqeuDe2k
# Get all songs info of 張洪量, 1TSaXDpyT2RdFIMGQfJ0xl
# Get all songs info of 張洪量, 2HYloFiLm9q0FA7ERriFY0
# Get all songs info of 張洪量, 3ECIAIlSX82SHVyxq4vHLM
# Get all songs info of 張洪量, 5ZxwnmWQemUKNLUn86wBhz
# Get all songs info of 張洪量, 3YruNwWzEgYx8AftOJyAji
# Get all songs info of Joi Chua, 6CiBK1yfiYZF97iqJ2UfcY
# Get all songs info of Joi Chua, 1J79pJCzLLiilzGGL061Nr
# Get all songs info of Joi Chua, 2oIXPsLHWUcnnZxW72i2WG
# Get all songs info of Joi Chua, 6EAVkUzyCZmAxu1jETZLAt
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-40-22583bb5d3de> in <module>
#       5
#       6     # get the song ids of each album
# ----> 7     song_al = sp.album_tracks(row['album_id'])['items']
#       8     for i in song_al:
#       9         d = {
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in album_tracks(self, album_id, limit, offset, market)
#     438         trid = self._get_id("album", album_id)
#     439         return self._get(
# --> 440             "albums/" + trid + "/tracks/", limit=limit, offset=offset, market=market
#     441         )
#     442
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
spf.sp.album_tracks('5clrYp291Dg0XL6rgvOgoB')['items'][0]
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2elBjNSdBE2Y3f0j1mjrql'},
#    'href': 'https://api.spotify.com/v1/artists/2elBjNSdBE2Y3f0j1mjrql',
#    'id': '2elBjNSdBE2Y3f0j1mjrql',
#    'name': 'Jay Chou',
#    'type': 'artist',
#    'uri': 'spotify:artist:2elBjNSdBE2Y3f0j1mjrql'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 226213,
#  'explicit': False,
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7KYm8KPa0Vujh7kClLE4Qo'},
#  'href': 'https://api.spotify.com/v1/tracks/7KYm8KPa0Vujh7kClLE4Qo',
#  'id': '7KYm8KPa0Vujh7kClLE4Qo',
#  'is_local': False,
#  'name': '床邊故事',
#  'preview_url': 'https://p.scdn.co/mp3-preview/1d5e98bf04131c69aa50a033b4b092acac3a49dc?cid=27c6faf8848a40aaa27cb34477c6d6be',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:7KYm8KPa0Vujh7kClLE4Qo'}

# %%
song_al_df = []
song_al = spf.sp.album_tracks('5clrYp291Dg0XL6rgvOgoB')['items']


for i in song_al:
    d = {
        'id': row['id'],
        'name': row['name'],
        'album_id': row['id'],
        'release_date': row['release_date'],
        'song_id': i['id'],
        'preview_url': i['preview_url']
    }
    song_al_df.append(d)
song_al_df = pd.DataFrame(song_al_df)
song_al_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-c4eaf1ffacd9> in <module>
#       5 for i in song_al:
#       6     d = {
# ----> 7         'id': row['id'],
#       8         'name': row['name'],
#       9         'album_id': row['id'],
#
# NameError: name 'row' is not defined

# %%
tr_al_df = []
song_id_list = song_al_df['song_id'].to_list()
tr_al = sp.tracks(song_id_list)['tracks']
for i in tr_al:
    d = {
        'song_id': i['id'],
        'popularity': i['popularity']
    }
    tr_al_df.append(d)
tr_al_df = pd.DataFrame(tr_al_df)

# %%
ft_al = sp.audio_features(song_al_df['song_id'].to_list())
ft_al_df = pd.DataFrame(ft_al)[['danceability', 'energy', 'key', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'type', 'id', 'duration_ms']]

ft_al_df = ft_al_df.rename(columns={"id": "song_id"})
ft_al_df
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.680   0.884    4    -6.508       0.0449      0.248000
# 1         0.522   0.829    1    -5.635       0.0317      0.002190
# 2         0.507   0.413    7    -7.490       0.0277      0.119000
# 3         0.630   0.922    9    -7.006       0.0332      0.277000
# 4         0.549   0.939    7    -5.968       0.0460      0.000106
# 5         0.441   0.619    4    -6.609       0.0293      0.190000
# 6         0.662   0.924    7    -6.473       0.0417      0.002030
# 7         0.590   0.572   11    -7.658       0.0379      0.192000
# 8         0.566   0.851    5    -5.549       0.0284      0.002020
# 9         0.411   0.671    2    -6.207       0.0319      0.011500
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000007    0.0951    0.539  106.012  audio_features
# 1          0.000000    0.0793    0.247  117.989  audio_features
# 2          0.000017    0.0886    0.172  133.966  audio_features
# 3          0.011100    0.1460    0.414  101.996  audio_features
# 4          0.012100    0.1270    0.428  118.988  audio_features
# 5          0.000000    0.1180    0.187   75.027  audio_features
# 6          0.206000    0.0940    0.602  114.015  audio_features
# 7          0.000000    0.1090    0.448  179.989  audio_features
# 8          0.000000    0.3500    0.552   93.009  audio_features
# 9          0.000000    0.1100    0.397   73.947  audio_features
#
#                   song_id  duration_ms
# 0  7KYm8KPa0Vujh7kClLE4Qo       226213
# 1  2dFvmGWAV9UW7vdDXhaxNL       266000
# 2  5rQPgfJMJ7yhsEr0HwTA77       221267
# 3  3ofIiWBhx82EwJACDA49fQ       200720
# 4  1QwOvYi1IS5s79dBjotcup       201747
# 5  7LyCtbxher5m97MImn5M3l       290133
# 6  2qm1nx1d1yAjYMZflBLNGC       195760
# 7  1ivCIgrYZyE0BvItL4Z8lk       215147
# 8  5jur8XerpNRx0kEV4bSdOF       174053
# 9  4zWz6OmFpyXIgQCxAS5yQb       285616

# %%
# Out:
# ['7KYm8KPa0Vujh7kClLE4Qo',
#  '2dFvmGWAV9UW7vdDXhaxNL',
#  '5rQPgfJMJ7yhsEr0HwTA77',
#  '3ofIiWBhx82EwJACDA49fQ',
#  '1QwOvYi1IS5s79dBjotcup',
#  '7LyCtbxher5m97MImn5M3l',
#  '2qm1nx1d1yAjYMZflBLNGC',
#  '1ivCIgrYZyE0BvItL4Z8lk',
#  '5jur8XerpNRx0kEV4bSdOF',
#  '4zWz6OmFpyXIgQCxAS5yQb']

# %%
sp.tracks(song_al_df['song_id'].to_list())['tracks'][0]['popularity']
sp.tracks(song_al_df['song_id'].to_list())['tracks'][0]['duration_ms']
sp.tracks(song_al_df['song_id'].to_list())['tracks'][0]['id']
# Out:
# '7KYm8KPa0Vujh7kClLE4Qo'

# %%
sp.tracks(song_al_df['song_id'].to_list())['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2elBjNSdBE2Y3f0j1mjrql'},
#     'href': 'https://api.spotify.com/v1/artists/2elBjNSdBE2Y3f0j1mjrql',
#     'id': '2elBjNSdBE2Y3f0j1mjrql',
#     'name': 'Jay Chou',
#     'type': 'artist',
#     'uri': 'spotify:artist:2elBjNSdBE2Y3f0j1mjrql'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5clrYp291Dg0XL6rgvOgoB'},
#   'href': 'https://api.spotify.com/v1/albums/5clrYp291Dg0XL6rgvOgoB',
#   'id': '5clrYp291Dg0XL6rgvOgoB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fb0610caa5ce0747743fb52e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fb0610caa5ce0747743fb52e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fb0610caa5ce0747743fb52e',
#     'width': 64}],
#   'name': '周杰倫的床邊故事',
#   'release_date': '2016-06-24',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:5clrYp291Dg0XL6rgvOgoB'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2elBjNSdBE2Y3f0j1mjrql'},
#    'href': 'https://api.spotify.com/v1/artists/2elBjNSdBE2Y3f0j1mjrql',
#    'id': '2elBjNSdBE2Y3f0j1mjrql',
#    'name': 'Jay Chou',
#    'type': 'artist',
#    'uri': 'spotify:artist:2elBjNSdBE2Y3f0j1mjrql'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 226213,
#  'explicit': False,
#  'external_ids': {'isrc': 'TWK971601301'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7KYm8KPa0Vujh7kClLE4Qo'},
#  'href': 'https://api.spotify.com/v1/tracks/7KYm8KPa0Vujh7kClLE4Qo',
#  'id': '7KYm8KPa0Vujh7kClLE4Qo',
#  'is_local': False,
#  'name': '床邊故事',
#  'popularity': 34,
#  'preview_url': 'https://p.scdn.co/mp3-preview/1d5e98bf04131c69aa50a033b4b092acac3a49dc?cid=27c6faf8848a40aaa27cb34477c6d6be',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:7KYm8KPa0Vujh7kClLE4Qo'}

# %%
track_df = []
for index, row in artist_df.iterrows():
    track = []
    # query the total number of tracks of a given artist
    tr = sp.search(q='artist:'+row['name'],limit=50,type='track')['tracks']
    print('Total number of tracks for '+row['name']+': '+str(tr['total']))
    # query all tracks info
    if tr['total']>50:
        for i in range(0, tr['total'], 50):
            track+=sp.search(q='artist:'+row['name'], limit=50, type='track', offset=i)['tracks']['items']
    else:
         track+=sp.search(q='artist:'+row['name'], limit=50, type='track')['tracks']['items']
    # create the df of track_id, 
    for i in track:
        d = {
            'id': row['id'],
            'track_id': i['id'],
            'duration_ms': i['duration_ms'],
            'release_date': i['album']['release_date'],
            'popularity': i['popularity']
        }
        track_df.append(d)
track_df = pd.DataFrame(track_df)
fid = data_dir.joinpath(f'tracks_genre-{genre}.tsv')
save_csv(track_df, fid)
# Out:
# Total number of tracks for Jay Chou: 390
# Total number of tracks for JJ Lin: 387
# Total number of tracks for Eason Chan: 1185
# Total number of tracks for G.E.M.: 367
# Total number of tracks for Eric Chou: 112
# Total number of tracks for Jacky Cheung: 913
# Total number of tracks for Jolin Tsai: 430
# Total number of tracks for Faye Wong: 733
# Total number of tracks for Mayday: 2471
# Total number of tracks for Stefanie Sun: 344
# Total number of tracks for Ren Ran: 806
# Total number of tracks for Joker Xue: 116
# Total number of tracks for Fish Leong: 315
# Total number of tracks for Hebe Tien: 270
# Total number of tracks for Karen Mok: 489
# Total number of tracks for Leehom Wang: 374
# Total number of tracks for A-Mei Chang: 411
# Total number of tracks for Teresa Teng: 3757
# Total number of tracks for Mao Buyi: 116
# Total number of tracks for Tanya Chua: 199
# Total number of tracks for Ronghao Li: 91
# Total number of tracks for Andy Lau: 1202
# Total number of tracks for S.H.E: 506
# Total number of tracks for Sandy Lam: 1054
# Total number of tracks for A-Lin: 31025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-a618ee023501> in <module>
#       8     if tr['total']>50:
#       9         for i in range(0, tr['total'], 50):
# ---> 10             track+=sp.search(q='artist:'+row['name'],limit=50,type='track')['tracks']['items']
#      11     # create the df of track_id,
#      12     for i in track:
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     546         """
#     547         return self._get(
# --> 548             "search", q=q, limit=limit, offset=offset, type=type, market=market
#     549         )
#     550
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
track = []
for i in range(0, tr['total'], 50):
    track+=sp.search(q='artist:'+'Eason Chan',limit=50,type='track')['tracks']['items']

# %%
track[0]['popularity']
# Out:
# 55

# %%
artist_df
# Out:
#                          id         name  followers
# 0    2elBjNSdBE2Y3f0j1mjrql     Jay Chou    2456028
# 1    7Dx7RhX0mFuXhCOUgB01uM       JJ Lin    1776088
# 2    2QcZxAgcs2I1q7CtCkl6MI   Eason Chan    1350569
# 3    7aRC4L63dBn3CiLDuWaLSI       G.E.M.    1574638
# 4    5fEQLwq1BWWQNR8GzhOIvi    Eric Chou     805933
# ..                      ...          ...        ...
# 565  7IhoiR1VotrcXWaviaSPNg     Nana Lee      10883
# 566  7lBz9amGhtwyMiwMUvlQwX          颜黎明        640
# 567  7vHny6pPDgjIHoVT9vNdne  10vacations        300
# 568  4ko19t9P3n3la4xALra1bk   Hagen Troy         61
# 569  4pqvGhGevu2moCcbRLEWxt          張小英       1362
#
# [570 rows x 3 columns]

# %%
def save_csv(data, fid):
    data.to_csv(fid, sep='\t', float_format='%.5f', na_rep='n/a', index=False)

# %%
def save_pickle(data, fid):
    open_file = open(fid, "wb")
    pickle.dump(data, open_file)
    open_file.close()

# %%
# outdir
out_dir = Path('/projects/hulacon/shared/nsd_results/yufei/codes_yufei/content/fc')
out_dir.mkdir(exist_ok=True, parents=True)
out_fid = out_dir.joinpath(
            f'sub-{sub_id}_fc.pkl')

open_file = open(out_fid, "wb")
pickle.dump(fc_features, open_file)
open_file.close()

# %%
# Out:
#                          id         name  followers
# 0    2elBjNSdBE2Y3f0j1mjrql     Jay Chou    2456028
# 1    7Dx7RhX0mFuXhCOUgB01uM       JJ Lin    1776088
# 2    2QcZxAgcs2I1q7CtCkl6MI   Eason Chan    1350569
# 3    7aRC4L63dBn3CiLDuWaLSI       G.E.M.    1574638
# 4    5fEQLwq1BWWQNR8GzhOIvi    Eric Chou     805933
# ..                      ...          ...        ...
# 565  7IhoiR1VotrcXWaviaSPNg     Nana Lee      10883
# 566  7lBz9amGhtwyMiwMUvlQwX          颜黎明        640
# 567  7vHny6pPDgjIHoVT9vNdne  10vacations        300
# 568  4ko19t9P3n3la4xALra1bk   Hagen Troy         61
# 569  4pqvGhGevu2moCcbRLEWxt          張小英       1362
#
# [570 rows x 3 columns]

# %%
sp.audio_features(['56wVfJKtnwlSZtC4NVgIrf'])
# Out:
# [{'danceability': 0.512,
#   'energy': 0.35,
#   'key': 10,
#   'loudness': -11.843,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.478,
#   'instrumentalness': 1.15e-06,
#   'liveness': 0.0855,
#   'valence': 0.343,
#   'tempo': 152.023,
#   'type': 'audio_features',
#   'id': '56wVfJKtnwlSZtC4NVgIrf',
#   'uri': 'spotify:track:56wVfJKtnwlSZtC4NVgIrf',
#   'track_href': 'https://api.spotify.com/v1/tracks/56wVfJKtnwlSZtC4NVgIrf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56wVfJKtnwlSZtC4NVgIrf',
#   'duration_ms': 222333,
#   'time_signature': 4}]

# %%
import librosa
from math import ceil

# %%
y, _ = librosa.load('/projects/hulacon/shared/nsd_results/yufei/spotify_analysis/data/preview_mp3/2o1mun3mrgfPLesJVJodQo.mp3')


class ParamsR:

    audio_len = 30
    srt = 22050 # default sample rate
    wsz = 4096 # samples per frame 
    mels = 128
    hop_length = wsz // 2 # determines the overlap between windows
    feat_len = int(ceil(srt * audio_len / float(hop_length)))

params = ParamsR
# Out:
# /home/peetal/.local/lib/python3.6/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
feat = librosa.feature.melspectrogram(
        y=y, sr=params.srt, n_fft=params.wsz,
        hop_length=params.hop_length, n_mels=params.mels)

# %%
feat
# Out:
# array([[1.1708965e+03, 6.9470453e+02, 1.4125255e+02, ..., 1.5560019e+02,
#         1.3932365e+02, 7.3504898e+01],
#        [6.6824556e+03, 3.8244651e+03, 8.0430762e+02, ..., 2.7518835e+02,
#         8.9813702e+02, 1.3332767e+03],
#        [1.5189962e+03, 8.5372607e+02, 2.5123970e+02, ..., 2.6697885e+02,
#         3.6892621e+02, 9.9287561e+02],
#        ...,
#        [4.1808486e-02, 1.8216912e-01, 8.0377555e-01, ..., 5.2339263e-02,
#         4.3328349e-02, 2.5055155e-01],
#        [3.0951913e-02, 3.3815037e-02, 1.9981806e-01, ..., 2.0913120e-02,
#         1.8973369e-02, 8.3663397e-02],
#        [4.4055209e-03, 1.6785861e-03, 1.5131173e-02, ..., 9.5728209e-04,
#         2.1050326e-03, 5.5263396e-03]], dtype=float32)

# %%
"""
script credit to https://github.com/OckhamsRazor/HSP_CNN
"""

import argparse
import glob
import multiprocessing
from functools import partial
from math import ceil
from os import mkdir, path
from shutil import rmtree
import librosa
import numpy as np
import warnings

# librosa.load will always raise a warning, ignore it
warnings.filterwarnings("ignore")

class ParamsR:

    audio_len = 30
    srt = 22050 # default sample rate
    wsz = 4096 # samples per frame 
    mels = 128
    hop_length = wsz // 2 # determines the overlap between windows
    feat_len = int(ceil(srt * audio_len / float(hop_length)))

params = ParamsR


def _feat_extract(fn, out_p):
    
    # get song id 
    sid = fn.split('/')[-1].split('.')[0]

    # Extract audio timeseries    
    y, sr = librosa.load(fn, sr=params.srt)
    song_len = len(y) / float(params.srt)

    if song_len < params.audio_len/2:
        print(sid)
        
    # Compute a melody-scaled spectrogram, shape = (n_mels, t)
    feat = librosa.feature.melspectrogram(
        y=y, sr=params.srt, n_fft=params.wsz,
        hop_length=params.hop_length, n_mels=params.mels)
    if song_len == params.audio_len:
        ret = feat
    elif song_len > params.audio_len: # select the middle 30s portion 
        start = feat.shape[1] // 2 - params.feat_len // 2
        end = feat.shape[1] // 2 + params.feat_len // 2
        if params.feat_len % 2 == 1:
            end += 1
        ret = feat[:, start:end]
    else: # padd it 
        ret = np.zeros((params.mels, params.feat_len))
        ret[:, :feat.shape[1]] = feat.copy()
    np.save(
        path.join(out_p, sid), ret.reshape(1, params.mels, params.feat_len))
    
    return 0  # success


def main():

    song_dir = './data/preview_mp3/'
    feat_dir = './mel_features/'
    if path.exists(feat_dir):
        rmtree(feat_dir)
    mkdir(feat_dir)

    songs = glob.glob('{}/*mp3'.format(song_dir))
    pool = multiprocessing.Pool(28)
    excpt = pool.map(partial(_feat_extract, out_p=feat_dir), songs[:])
    pool.close()
    pool.join()
    #for fn in songs: 
    #    _feat_extract(fn, out_p=feat_dir)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ebe1e0b6fdfa> in <module>
#      80
#      81 if __name__ == "__main__":
# ---> 82     main()
#
# <ipython-input-12-ebe1e0b6fdfa> in main()
#      72     songs = glob.glob('{}/*mp3'.format(song_dir))
#      73     pool = multiprocessing.Pool(28)
# ---> 74     excpt = pool.map(partial(_feat_extract, out_p=feat_dir), songs[:])
#      75     pool.close()
#      76     pool.join()
#
# /packages/miniconda/20190102/envs/anaconda-tensorflow-gpu/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /packages/miniconda/20190102/envs/anaconda-tensorflow-gpu/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /packages/miniconda/20190102/envs/anaconda-tensorflow-gpu/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /packages/miniconda/20190102/envs/anaconda-tensorflow-gpu/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /packages/miniconda/20190102/envs/anaconda-tensorflow-gpu/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
